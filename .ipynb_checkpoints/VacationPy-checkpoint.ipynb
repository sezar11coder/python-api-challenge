# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# 'b1f3ca1ea2d84fea80a087fae806595b'

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv",index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          stanley  54.8680   -1.6985     48.22        87         100
# 1          tuy hoa  13.0833  109.3000     75.79        92          87
# 2           igarka  67.4667   86.5833     17.87        95          67
# 3        adamstown -25.0660 -130.1015     70.38        80          97
# 4            lihue  21.9789 -159.3672     83.79        71          20
#
#          Wind Speed Country        Date
# City_ID
# 0              2.30      GB  1730763178
# 1              3.11      VN  1730763179
# 2             11.23      RU  1730763180
# 3             20.56      PN  1730763086
# 4             12.66      US  1730763182

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
#%%capture --no-display
base_url = "https://maps.geoapify.com/v1/staticmap"
# Configure the map plot
map_plot = city_data_df.hvplot.points(
    'Lng', 'Lat',       # Longitude and Latitude for coordinate
    geo=True,           # Enable geospatial plotting
    color='City',       # Color of points
    size='Humidity',    # Set size based on humidity levels
    tiles='OSM',        # Use OpenStreetMap as the tile layer
    frame_width=700,    # Set the width of the plot
    frame_height=500,   # Set the height of the plot
    scale=0.8,
    title="City Humidity Levels"
    
)
  # YOUR CODE HERE

# Display the map
map_plot
# YOUR CODE HERE
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
Temperature
ideal_cities_df = city_data_df[
    (city_data_df["Max Temp"] <= 85) & 
    (city_data_df["Max Temp"] >=60 ) &
    (city_data_df["Humidity"] < 60) & 
    (city_data_df["Cloudiness"] < 20) &
    (city_data_df["Wind Speed"] < 8.5)

]
# YOUR CODE HERE

# Drop any rows with null values
ideal_cities_df = ideal_cities_df.dropna()  # YOUR CODE HERE

# Display sample data
ideal_cities_df # YOUR CODE HERE
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 10                   sur  22.5667   59.5289     80.85        51           2
# 45         blackmans bay -43.0167  147.3167     63.52        53           1
# 50                riyadh  24.6877   46.7219     74.93        29           0
# 71                  taft  31.7471   54.2088     60.75        39           0
# 77                newman  37.3138 -121.0208     70.03        29           1
# 88                bardai  11.6500    7.2333     67.23        29           3
# 97         selebi-phikwe -21.9790   27.8498     72.23        19           0
# 146              mangrol  21.1167   70.1167     79.99        58           0
# 156             kerikeri -35.2268  173.9474     66.87        43           1
# 175           codrington -38.2667  141.9667     65.46        47           3
# 203        mount gambier -37.8333  140.7667     66.78        40           3
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_cities_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy() # YOUR CODE HERE

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = "" # YOUR CODE HERE

# Display sample data
hotel_df # YOUR CODE HERE
# Out:
#                     City Country      Lat       Lng  Humidity Hotel Name
# City_ID
# 10                   sur      OM  22.5667   59.5289        51
# 45         blackmans bay      AU -43.0167  147.3167        53
# 50                riyadh      SA  24.6877   46.7219        29
# 71                  taft      IR  31.7471   54.2088        39
# 77                newman      US  37.3138 -121.0208        29
# 88                bardai      NG  11.6500    7.2333        29
# 97         selebi-phikwe      BW -21.9790   27.8498        19
# 146              mangrol      IN  21.1167   70.1167        58
# 156             kerikeri      NZ -35.2268  173.9474        43
# 175           codrington      AU -38.2667  141.9667        47
# 203        mount gambier      AU -37.8333  140.7667        40
# 206              awjilah      LY  29.1081   21.2869        45
# 237                aswan      EG  24.0934   32.9070        48
# 241      sharm el-sheikh      EG  27.8518   34.3050        43
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000 # YOUR CODE HERE
params = { "categories": "accommodation.hotel",  
    "apiKey": geoapify_key,               
    "limit": 1    
    
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row["Lat"]
    lon = row["Lng"]
   

    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lon},{lat},{radius}"  # YOUR CODE HERE
    params["bias"] = f"proximity:{lon},{lat}"  # YOUR CODE HERE

    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionary
    name_address = requests.get(base_url, params=params) # YOUR CODE HERE

    # Convert the API response to JSON format
    name_address = name_address.json() # YOUR CODE HERE

    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# sur - nearest hotel: Sur Hotel
# blackmans bay - nearest hotel: Villa Howden
# riyadh - nearest hotel: White Palace Hotel
# taft - nearest hotel: هتل شیرکوه تفت
# newman - nearest hotel: No hotel found
# bardai - nearest hotel: No hotel found
# selebi-phikwe - nearest hotel: Cresta Bosele Hotel
# mangrol - nearest hotel: No hotel found
# kerikeri - nearest hotel: Avalon Resort
# codrington - nearest hotel: No hotel found
# mount gambier - nearest hotel: The Old Mount Gambier Gaol
# awjilah - nearest hotel: No hotel found
# aswan - nearest hotel: Oscar Hotel
# sharm el-sheikh - nearest hotel: Club El Faraana
# kayes - nearest hotel: No hotel found
# isna - nearest hotel: No hotel found
# ghat - nearest hotel: فندق تاسيلي
# suratgarh - nearest hotel: The Golden Inn
# wamba - nearest hotel: No hotel found
# iranshahr - nearest hotel: هتل قصِر
# as sulayyil - nearest hotel: No hotel found
# whangarei - nearest hotel: Grand Hotel
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = hotel_df.hvplot.points(
    'Lng', 'Lat',           
    geo=True,               
    color='blue',           
    size='Humidity',        
    tiles='OSM',            
    frame_width=800,       
    frame_height=600,       
    title="City Humidity Levels with Nearby Hotels",
    hover_cols=['City', 'Country', 'Hotel Name']  # Add hover information
)


# Display the map
map_plot
# YOUR CODE HERE
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (Humidity,City,Country,Hotel Name)
